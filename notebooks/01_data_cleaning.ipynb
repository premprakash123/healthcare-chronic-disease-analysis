# %%
import pandas as pd

df = pd.read_csv("../data/processed/ckd_clean_initial.csv")

df.head()
# Out:
#    id 'age' 'bp'   'sg' 'al' 'su'   'rbc'      'pc'       'pcc'        'ba'  \
# 0   1    48   80   1.02    1    0       ?    normal  notpresent  notpresent
# 1   2     7   50   1.02    4    0       ?    normal  notpresent  notpresent
# 2   3    62   80   1.01    2    3  normal    normal  notpresent  notpresent
# 3   4    48   70  1.005    4    0  normal  abnormal     present  notpresent
# 4   5    51   80   1.01    2    0  normal    normal  notpresent  notpresent
#
#    ... 'wbcc' 'rbcc' 'htn' 'dm' 'cad' 'appet' 'pe' 'ane' 'class' Unnamed: 26
# 0  ...   7800    5.2   yes  yes    no    good   no    no     ckd         NaN
# 1  ...   6000      ?    no   no    no    good   no    no     ckd         NaN
# 2  ...   7500      ?    no  yes    no    poor   no   yes     ckd         NaN
# 3  ...   6700    3.9   yes   no    no    poor  yes   yes     ckd         NaN
# 4  ...   7300    4.6    no   no    no    good   no    no     ckd         NaN
#
# [5 rows x 27 columns]
